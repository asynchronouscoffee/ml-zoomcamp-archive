# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 2.2 Data Preparation

# %%
#url = 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/blob/master/chapter-02-car-price/data.csv'
#!wget $url

# %%
df = pd.read_csv('car-price.csv')

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df['Transmission Type']
# Out:
# 0           MANUAL
# 1           MANUAL
# 2           MANUAL
# 3           MANUAL
# 4           MANUAL
#            ...
# 11909    AUTOMATIC
# 11910    AUTOMATIC
# 11911    AUTOMATIC
# 11912    AUTOMATIC
# 11913    AUTOMATIC
# Name: Transmission Type, Length: 11914, dtype: object

# %%
df.columns = df.columns.str.lower().str.replace(' ','_')

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# msrp                   int64
# dtype: object

# %%
# Selecting object columns
str = list(df.dtypes[df.dtypes == 'object'].index)
str
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %% [markdown]
# Save the object columns into string to standardize it values automatically later.

# %%
# Standardize all values in str using for loop
for col in str:
    df[col] = df[col].str.lower().str.replace(' ','_')

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %% [markdown]
# # 2.3 Exploratory Data Analysis

# %%
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          bmw  1_series_m  2011     premium_unleaded_(required)      335.0
# 1          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 2          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 3          bmw    1_series  2011     premium_unleaded_(required)      230.0
# 4          bmw    1_series  2011     premium_unleaded_(required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11910    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11911    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11912    acura         zdx  2013  premium_unleaded_(recommended)      300.0
# 11913  lincoln      zephyr  2006                regular_unleaded      221.0
#
# ...

# %%
# Checking all columns and its values
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# make
# ['bmw' 'audi' 'fiat' 'mercedes-benz' 'chrysler']
# 48
#
# model
# ['1_series_m' '1_series' '100' '124_spider' '190-class']
# 914
#
# year
# [2011 2012 2013 1992 1993]
# 28
#
# engine_fuel_type
# ['premium_unleaded_(required)' 'regular_unleaded'
#  'premium_unleaded_(recommended)' 'flex-fuel_(unleaded/e85)' 'diesel']
# 10
#
# engine_hp
# [335. 300. 230. 320. 172.]
# 356
#
# engine_cylinders
# [ 6.  4.  5.  8. 12.]
# 9
#
# transmission_type
# ['manual' 'automatic' 'automated_manual' 'direct_drive' 'unknown']
# 5
#
# driven_wheels
# ['rear_wheel_drive' 'front_wheel_drive' 'all_wheel_drive'
#  'four_wheel_drive']
# 4
#
# number_of_doors
# [ 2.  4.  3. nan]
# 3
#
# market_category
# ['factory_tuner,luxury,high-performance' 'luxury,performance'
#  'luxury,high-performance' 'luxury' 'performance']
# 71
#
# vehicle_size
# ['compact' 'midsize' 'large']
# 3
#
# vehicle_style
# ['coupe' 'convertible' 'sedan' 'wagon' '4dr_hatchback']
# 16
#
# highway_mpg
# [26 28 27 25 24]
# 59
#
# ...

# %% [markdown]
# **Looking at the Distribution of Price**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.histplot(df.msrp, bins=50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %% [markdown]
# le6 = $10^6$. That is 1.000.000
#
# The type of distribution above is called "Long Tail Distribution", because of the long flat distribution. This kind of distribution is not good as a training materials for machine learning, so we need to remove those 'tail'.

# %%
sns.histplot(df.msrp[df.msrp < 100000], bins=50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
# Normalize the data using logarithm
price_log = np.log1p(df.msrp)

# %%
price_log
# Out:
# 0        10.739349
# 1        10.612779
# 2        10.500977
# 3        10.290483
# 4        10.448744
#            ...
# 11909    10.739024
# 11910    10.945018
# 11911    10.832122
# 11912    10.838031
# 11913    10.274913
# Name: msrp, Length: 11914, dtype: float64

# %%
sns.histplot(price_log, bins=50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %% [markdown]
# Now, the distribution looks more compact. It now looked like normal distribution because of the curve in the middle. Now, this is a good materials as a target variable for the model training.

# %% [markdown]
# **Checking the Missing Values**

# %%
df.isnull().sum()
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       30
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3742
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# msrp                    0
# dtype: int64

# %% [markdown]
# # 2.4 Setting Up the Validation Framework

# %% [markdown]
# The data will be splitted into 60% of training data, 20% of validation data, and 20% of test data.

# %%
# Checking the size of data
n = len(df)

n_test = int(n * 0.2)
print('size of test data: ', n_test)

n_val = int(n * 0.2)
print('size of validation data: ', n_val)

n_train = n - n_val - n_test
print('size of training data: ', n_train)

print('total size of data: ', n, n_val + n_test + n_train)
# Out:
# size of test data:  2382
# size of validation data:  2382
# size of training data:  7150
# total size of data:  11914 11914

# %%
# Splitting the data
df_train = df.iloc[:n_train]
df_val = df.iloc[n_train:n_train+n_val]
df_test = df.iloc[n_train+n_val:]

# %%
df_val
# Out:
#            make           model  year          engine_fuel_type  engine_hp  \
# 7150    lincoln       navigator  2015          regular_unleaded      365.0
# 7151    lincoln       navigator  2016          regular_unleaded      380.0
# 7152    lincoln       navigator  2016          regular_unleaded      380.0
# 7153    lincoln       navigator  2016          regular_unleaded      380.0
# 7154    lincoln       navigator  2016          regular_unleaded      380.0
# ...         ...             ...   ...                       ...        ...
# 9527  chevrolet  silverado_1500  2015  flex-fuel_(unleaded/e85)      285.0
# 9528  chevrolet  silverado_1500  2015          regular_unleaded      355.0
# 9529  chevrolet  silverado_1500  2015          regular_unleaded      355.0
# 9530  chevrolet  silverado_1500  2015          regular_unleaded      355.0
# 9531  chevrolet  silverado_1500  2015          regular_unleaded      355.0
#
# ...

# %%
df_test
# Out:
#             make           model  year                engine_fuel_type  \
# 9532   chevrolet  silverado_1500  2015                regular_unleaded
# 9533   chevrolet  silverado_1500  2015        flex-fuel_(unleaded/e85)
# 9534   chevrolet  silverado_1500  2015        flex-fuel_(unleaded/e85)
# 9535   chevrolet  silverado_1500  2015        flex-fuel_(unleaded/e85)
# 9536   chevrolet  silverado_1500  2015        flex-fuel_(unleaded/e85)
# ...          ...             ...   ...                             ...
# 11909      acura             zdx  2012     premium_unleaded_(required)
# 11910      acura             zdx  2012     premium_unleaded_(required)
# 11911      acura             zdx  2012     premium_unleaded_(required)
# 11912      acura             zdx  2013  premium_unleaded_(recommended)
# 11913    lincoln          zephyr  2006                regular_unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_train
# Out:
#          make       model  year             engine_fuel_type  engine_hp  \
# 0         bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1         bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2         bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3         bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4         bmw    1_series  2011  premium_unleaded_(required)      230.0
# ...       ...         ...   ...                          ...        ...
# 7145    mazda      navajo  1994             regular_unleaded      160.0
# 7146    mazda      navajo  1994             regular_unleaded      160.0
# 7147  lincoln   navigator  2015             regular_unleaded      365.0
# 7148  lincoln   navigator  2015             regular_unleaded      365.0
# 7149  lincoln   navigator  2015             regular_unleaded      365.0
#
#       engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# ...

# %% [markdown]
# There is a problem right there. The data is splitted sequentially, so, each data split is containing small variance of data. We need to shuffle it.

# %%
# Generate the sequence a number from 1 to n
idx = np.arange(n)
idx
# Out:
# array([    0,     1,     2, ..., 11911, 11912, 11913])

# %%
# Perform the shuffle task
np.random.seed(2)
np.random.shuffle(idx)
idx
# Out:
# array([2735, 6720, 5878, ..., 6637, 2575, 7336])

# %%
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train+n_val]]
df_test = df.iloc[idx[n_train+n_val:]]

# %%
df_train
# Out:
#               make        model  year                engine_fuel_type  \
# 2735     chevrolet       cobalt  2008                regular_unleaded
# 6720        toyota       matrix  2012                regular_unleaded
# 5878        subaru      impreza  2016                regular_unleaded
# 11190   volkswagen      vanagon  1991                regular_unleaded
# 4554          ford        f-150  2017        flex-fuel_(unleaded/e85)
# ...            ...          ...   ...                             ...
# 434            bmw     4_series  2015     premium_unleaded_(required)
# 1902    volkswagen       beetle  2015  premium_unleaded_(recommended)
# 9334           gmc  sierra_1500  2015        flex-fuel_(unleaded/e85)
# 5284   rolls-royce        ghost  2014     premium_unleaded_(required)
# 2420    volkswagen           cc  2017  premium_unleaded_(recommended)
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_val
# Out:
#                 make                    model  year  \
# 2779       chevrolet                 colorado  2015
# 3708   mercedes-benz                  e-class  2017
# 4794            ford                    focus  2017
# 10498          acura                      tlx  2016
# 1880      volkswagen       beetle_convertible  2016
# ...              ...                      ...   ...
# 11123          volvo                      v60  2015
# 5549        maserati  granturismo_convertible  2015
# 4146        cadillac          escalade_hybrid  2013
# 6337      mitsubishi                   lancer  2016
# 9814             kia                  sorento  2015
#
#                      engine_fuel_type  engine_hp  engine_cylinders  \
# 2779                 regular_unleaded      200.0               4.0
# 3708      premium_unleaded_(required)      241.0               4.0
# 4794         flex-fuel_(unleaded/e85)      160.0               4.0
# ...

# %%
df_test
# Out:
#                 make           model  year          engine_fuel_type  \
# 11195            gmc         vandura  1994          regular_unleaded
# 673    mercedes-benz       600-class  1993          regular_unleaded
# 11270         toyota           venza  2013          regular_unleaded
# 752            volvo             740  1992          regular_unleaded
# 3137            ford  crown_victoria  2010  flex-fuel_(unleaded/e85)
# ...              ...             ...   ...                       ...
# 2514       chevrolet       chevy_van  1998          regular_unleaded
# 11798         subaru    xv_crosstrek  2014          regular_unleaded
# 6637           dodge          magnum  2006          regular_unleaded
# 2575           honda           civic  2016          regular_unleaded
# 7336          subaru         outback  2015          regular_unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
print('len of df_train: ', len(df_train))
print('len of df_val: ', len(df_val))
print('len of df_test: ', len(df_test))
# Out:
# len of df_train:  7150
# len of df_val:  2382
# len of df_test:  2382

# %% [markdown]
# We actually doesn't need the information about the number of index. So, we need to delete it with reset index method.

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
df_val.head()
# Out:
#             make               model  year                engine_fuel_type  \
# 0      chevrolet            colorado  2015                regular_unleaded
# 1  mercedes-benz             e-class  2017     premium_unleaded_(required)
# 2           ford               focus  2017        flex-fuel_(unleaded/e85)
# 3          acura                 tlx  2016  premium_unleaded_(recommended)
# 4     volkswagen  beetle_convertible  2016                regular_unleaded
#
#    engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 0      200.0               4.0         automatic   four_wheel_drive
# 1      241.0               4.0         automatic    all_wheel_drive
# 2      160.0               4.0            manual  front_wheel_drive
# 3      290.0               6.0         automatic  front_wheel_drive
# 4      170.0               4.0         automatic  front_wheel_drive
#
#    number_of_doors market_category vehicle_size        vehicle_style  \
# ...

# %% [markdown]
# Now, we need to transform the target variable and separate it from the features variables.

# %%
y_train = np.log1p(df_train.msrp.values)
y_val = np.log1p(df_val.msrp.values)
y_test = np.log1p(df_test.msrp.values)

# %%
print(y_train)
print(len(y_train))
# Out:
# [ 9.57574708  9.887663    9.89323518 ... 10.45380308 12.62248099
#  10.54061978]
# 7150

# %%
print(y_val)
print(len(y_val))
# Out:
# [10.19936098 10.90872279  9.72770457 ... 11.21756062  9.77542688
#  10.1924563 ]
# 2382

# %%
print(y_test)
print(len(y_test))
# Out:
# [ 7.60140233  8.07464908 10.34563811 ... 10.27852782 10.00789261
#  10.40414162]
# 2382

# %%
# Delete the target variables from features matrix
del df_train['msrp']
del df_val['msrp']
del df_test['msrp']

# %% [markdown]
# # 2.5 Linear Regression

# %% [markdown]
# The formula for this task is $g(X) = y$. Where $g$ is the model, $(X)$ is feature matrix, and $y$ is target matrix.
#
# The simplified version is $g(x_i) = y_i$. Where $x_i$ is a car, and $y_i$ is it's price.
#
# For this training, we will take the column of engine_hp, city_mpg, and popularity as a features.

# %%
# For demonstration, we will use 10 row of df_train
df_train.iloc[10]
# Out:
# make                                 rolls-royce
# model                     phantom_drophead_coupe
# year                                        2015
# engine_fuel_type     premium_unleaded_(required)
# engine_hp                                  453.0
# engine_cylinders                            12.0
# transmission_type                      automatic
# driven_wheels                   rear_wheel_drive
# number_of_doors                              2.0
# market_category        exotic,luxury,performance
# vehicle_size                               large
# vehicle_style                        convertible
# highway_mpg                                   19
# city_mpg                                      11
# popularity                                    86
# Name: 10, dtype: object

# %%
xi = [453, 11, 86]

# %%
# Define the weights
w0 = 7.17
w = [0.01, 0.04, 0.002]

# %%
# Define the lr (simple one)
def lr(xi):
    n = len(xi)

    pred = w0

    for j in range(n):
        pred = pred + w[j] * xi[j]

    return pred

# %% [markdown]
# How the model works is:
# $g(x_i) = w_0 + w_1 . x_1 + w_2 . x_2 + w_3 . x_3$
#
# $w_0$ is bias, $x_1$ is engine_hp, $x_2$ is city_mpg, and $x_3$ is popularity.
#
# The simplified formula is:
# $g(\mathbf{x}_i) = W_0 + \sum_{j=0}^{n-1} W_j \cdot x_{ij}$

# %%
# test the lr
lr(xi)
# Out:
# 12.312

# %% [markdown]
# The computation is:
# $7.17 + 453 * 0.01 + 11 * 0.04 + 86 * 0.002 = 12.312$
#
# Further explanation:
# - $W0$ is the bias, like the knowledge you know about cars. In there, you might have a bias, strong one or weak one.
# - $w_i$ is the weight. It helps to determine the importance of the feature for the prediction. Like for example, we can give more weights to the most important features.

# %% [markdown]
# We need to do a $log(y+1)$ to make the prediction more logical.

# %%
# Getting the exponents
np.expm1(12.312)
# Out:
# np.float64(222347.2221101062)

# %%
# This will undo the pred
np.log1p(222347.2221101062)
# Out:
# np.float64(12.312)

# %% [markdown]
# # 2.6 Linear Regression: Vector Form

# %% [markdown]
# The calculation of summation in Linear Regression is a dot product, the multiplication of vector to vector.
#
# The formula of the dot product can be written like this: $W_0 + \mathbf{x}_i^T \mathbf{w}$

# %%
# Code implementation of dot product
def dot(xi, w):
    n = len(xi)

    res = 0.0

    for j in range(n):
        res = res + xi[j] * w[j]

    return res

# %%
def lr(xi):
    return w0 + dot(xi, w)

# %% [markdown]
# The vector is:
# - $W = [W_0, W_1, W_2, ...W_n] n+1$ dimension.
# - $X_i = [X_{i0}, X_{i1}, X_{i2}, ...X_{in}]$ where $X_{i0}$ always 1.
#
# The dot product is: $W^T X_i = X_i^T W = W_0 + $...

# %%
# Insert w0 into weight vector to make it shorter
w_new = [w0] + w
w_new
# Out:
# [7.17, 0.01, 0.04, 0.002]

# %%
def lr(xi):
    xi = [1] + xi
    return dot(xi, w_new)

# %%
lr(xi)
# Out:
# 12.312

# %%
# Re-define data example
w0 = 7.17
w = [0.01, 0.04, 0.002]
w_new = [w0] + w

# %%
x1 = [1, 148, 24, 1385]
x2 = [1, 132, 25, 2031]
x10 = [1, 453, 11, 86]

# Put data into matrix
X = [x1, x2, x10]
X = np.array(X)
X
# Out:
# array([[   1,  148,   24, 1385],
#        [   1,  132,   25, 2031],
#        [   1,  453,   11,   86]])

# %%
# Perform the matrix matrix multiplication of X and w_new
def lr(X):
    return X.dot(w_new)

# %%
lr(X)
# Out:
# array([12.38 , 13.552, 12.312])

# %% [markdown]
# # Training Linear Regression Model
